# %% [markdown]
# # Лабораторная работа 1
# ## Исследование набора данных лучших реперов России

# %% [markdown]
# ### Подключение библиотеки NumPy и загрузка данных

# %%
# !wget https://raw.githubusercontent.com/Hilolll/AI_Machine_Learning_1/main/data%20and%20code/data.data
# Out:
# --2024-05-08 12:18:23--  https://raw.githubusercontent.com/Hilolll/AI_Machine_Learning_1/main/data%20and%20code/data.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12412 (12K) [text/plain]
# Saving to: ‘data.data’
#
# data.data           100%[===================>]  12.12K  --.-KB/s    in 0s
#
# 2024-05-08 12:18:23 (66.4 MB/s) - ‘data.data’ saved [12412/12412]

# %%
import numpy as np
data_path = "data.data"
data = np.genfromtxt(data_path, delimiter=",")
print(data)
# Out:
# [[0.65470774 1.32778732 0.715325   0.62643429        nan]
#  [1.0458639  0.86725731 0.87577278 1.08952132        nan]
#  [0.71761743 0.74301384 0.72130296 0.42355074        nan]
#  [0.94024165 0.87822141 0.76043648 0.34486606        nan]
#  [0.737043   0.6165403  0.95807994 0.41990025        nan]
#  [0.80862596 1.02668241 0.77472992 0.42804985        nan]
#  [0.63642895 0.59233843 0.92479211 1.10160944        nan]
#  [1.33668452 0.6040617  0.73828698 0.43275646        nan]
#  [0.99879997 0.70443499 0.90181486 0.44307181        nan]
#  [1.33373717 1.1394576  0.64483607 1.48927414        nan]
#  [0.65731169 0.99784549 0.87829585 0.45934317        nan]
#  [0.61327064 0.90539829 0.65932184 1.16673489        nan]
#  [0.72092199 0.58048204 0.68946221 0.46468627        nan]
#  [0.62390568 0.59609925 0.63919128 0.44901215        nan]
#  [0.75576944 0.67892555 0.60711236 0.66481749        nan]
#  [0.94598879 0.75753845 1.04974673 0.69274454        nan]
# ...

# %% [markdown]
# ### Тип переменной и форма (shape)

# %%
print ( "Data type : ", type(data) )
print ( "Data shape : ", data.shape )
print ( data[-4:] )
# Out:
# Data type :  <class 'numpy.ndarray'>
# Data shape :  (150, 5)
# [[0.57197691 0.57759045 0.58844675 2.31417716        nan]
#  [0.60893118 0.5096693  0.52807376 1.81217745        nan]
#  [0.60893118 0.5096693  0.52807376 1.81217745        nan]
#  [1.16064651 1.16590185 0.5975896  1.75844532        nan]]

# %% [markdown]
# ### Получение типа набора данных, строки, элемента

# %%
data1 = np.genfromtxt(data_path, delimiter=",", dtype=None)
print('Shape of the dataset:', data1.shape)
print('Dataset type:', type(data1))
print('A single row of the dataset is type of:', type(data1[0]))
print('Types of elements:', type(data1[0][1]), type(data1[0][4]))
print('Dataset:')
print(data1)
# Out:
# Shape of the dataset: (150,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.bytes_'>
# Dataset:
# [(0.65470774, 1.32778732, 0.715325  , 0.62643429, b'Skryptonite')
#  (1.0458639 , 0.86725731, 0.87577278, 1.08952132, b'Skryptonite')
#  (0.71761743, 0.74301384, 0.72130296, 0.42355074, b'Skryptonite')
#  (0.94024165, 0.87822141, 0.76043648, 0.34486606, b'Skryptonite')
#  (0.737043  , 0.6165403 , 0.95807994, 0.41990025, b'Skryptonite')
#  (0.80862596, 1.02668241, 0.77472992, 0.42804985, b'Skryptonite')
#  (0.63642895, 0.59233843, 0.92479211, 1.10160944, b'Skryptonite')
#  (1.33668452, 0.6040617 , 0.73828698, 0.43275646, b'Skryptonite')
#  (0.99879997, 0.70443499, 0.90181486, 0.44307181, b'Skryptonite')
#  (1.33373717, 1.1394576 , 0.64483607, 1.48927414, b'Skryptonite')
#  (0.65731169, 0.99784549, 0.87829585, 0.45934317, b'Skryptonite')
# ...

# %% [markdown]
# ### Указание типа столбцов при загрузке данных

# %%
dt = np.dtype("f8, f8, f8, f8, U30")
data2 = np.genfromtxt(data_path, delimiter=",", dtype=dt)
print('Shape of the dataset:', data2.shape)
print('Dataset type:', type(data2))
print('A single row of the dataset is type of:', type(data2[0]))
print('Types of elements:', type(data2[0][1]), type(data2[0][4]))
print('Dataset slice:')
print(data2[:10])
# Out:
# Shape of the dataset: (150,)
# Dataset type: <class 'numpy.ndarray'>
# A single row of the dataset is type of: <class 'numpy.void'>
# Types of elements: <class 'numpy.float64'> <class 'numpy.str_'>
# Dataset slice:
# [(0.65470774, 1.32778732, 0.715325  , 0.62643429, 'Skryptonite')
#  (1.0458639 , 0.86725731, 0.87577278, 1.08952132, 'Skryptonite')
#  (0.71761743, 0.74301384, 0.72130296, 0.42355074, 'Skryptonite')
#  (0.94024165, 0.87822141, 0.76043648, 0.34486606, 'Skryptonite')
#  (0.737043  , 0.6165403 , 0.95807994, 0.41990025, 'Skryptonite')
#  (0.80862596, 1.02668241, 0.77472992, 0.42804985, 'Skryptonite')
#  (0.63642895, 0.59233843, 0.92479211, 1.10160944, 'Skryptonite')
#  (1.33668452, 0.6040617 , 0.73828698, 0.43275646, 'Skryptonite')
#  (0.99879997, 0.70443499, 0.90181486, 0.44307181, 'Skryptonite')
#  (1.33373717, 1.1394576 , 0.64483607, 1.48927414, 'Skryptonite')]

# %% [markdown]
# ### Построение графиков с использованием Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# Данные из отдельных столбцов
drums_Energy = [] # Drums Energy
variety_of_musical_instruments = [] # Variety of musical instruments
harmonic_richness = [] # Harmonic Richness
emotional_intensity = [] # Emotional Intensity

# Выполняем обход всей данных data2
for dot in data2:
    drums_Energy.append(dot[0])
    variety_of_musical_instruments.append(dot[1])
    harmonic_richness.append(dot[2])
    emotional_intensity.append(dot[3])


plt.figure(1)
setosa, = plt.plot(drums_Energy[:50], variety_of_musical_instruments[:50], 'ro', label='Skryptonite')
versicolor, = plt.plot(drums_Energy[50:100], variety_of_musical_instruments[50:100], 'g^', label='INSTASAMKA')
virginica, = plt.plot(drums_Energy[100:150], variety_of_musical_instruments[100:150], 'bs', label='Big Baby Tape')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')

plt.figure(2)
setosa, = plt.plot(drums_Energy[:50], harmonic_richness[:50], 'ro', label='Skryptonite')
versicolor, = plt.plot(drums_Energy[50:100], harmonic_richness[50:100], 'g^', label='INSTASAMKA')
virginica, = plt.plot(drums_Energy[100:150], harmonic_richness[100:150], 'bs', label='Big Baby Tape')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')

plt.figure(3)
setosa, = plt.plot(drums_Energy[:50], emotional_intensity[:50], 'ro', label='Skryptonite')
versicolor, = plt.plot(drums_Energy[50:100], emotional_intensity[50:100], 'g^', label='INSTASAMKA')
virginica, = plt.plot(drums_Energy[100:150], emotional_intensity[100:150], 'bs', label='Big Baby Tape')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')

plt.show()
